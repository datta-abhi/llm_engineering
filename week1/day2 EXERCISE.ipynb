# %% [markdown]
# # Welcome to your first assignment!
#
# Instructions are below. Please give this a try, and look in the solutions folder if you get stuck (or feel free to ask me!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get to the assignment --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# removing any unused layers ⠋ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# removing any unused layers
# success

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
# print(response.json()['message']['content'])

# %%
response.json()
# Out:
# {'model': 'llama3.2',
#  'created_at': '2025-01-05T13:38:56.6620198Z',
#  'message': {'role': 'assistant',
#   'content': 'Generative AI has numerous business applications across various industries, including:\n\n1. **Content Generation**: AI-powered tools can generate high-quality content such as blog posts, articles, social media posts, product descriptions, and more.\n2. **Product Design**: Generative AI can assist in designing products by generating 3D models, sketches, and prototypes. This is particularly useful for companies that need to produce complex products quickly.\n3. **Image and Video Generation**: AI-generated images and videos can be used in advertising, marketing, entertainment, and other industries where visual content is crucial.\n4. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants, enabling them to generate responses to customer inquiries and provide personalized support.\n5. **Music Composition and Sound Design**: AI-generated music and sound effects can be used in film scores, video games, and advertising campaigns.\n6. **Data Analysis and Insights**: Generative AI can analyze large datasets and generate insights, predictions, and recommendations for businesses.\n7. **Personalization**: AI-powered systems can generate personalized content, offers, and experiences tailored to individual customers\' preferences and behaviors.\n8. **Marketing Automation**: Generative AI can automate marketing tasks such as email marketing, social media management, and lead generation.\n9. **Virtual Reality (VR) and Augmented Reality (AR)**: AI-generated 3D models and environments can be used in VR and AR experiences, creating immersive and interactive experiences for customers.\n10. **Supply Chain Optimization**: Generative AI can analyze supply chain data and generate optimized logistics plans, reducing costs and improving efficiency.\n\nSome specific business applications of Generative AI include:\n\n* **Product recommendation engines**: Amazon\'s "Recommended for you" feature uses Generative AI to suggest products based on user behavior and preferences.\n* **Content marketing platforms**: HubSpot\'s content management platform uses Generative AI to generate blog posts, social media posts, and other content.\n* **Customer service chatbots**: Many companies use Generative AI-powered chatbots to provide 24/7 customer support.\n* **Personalized advertising**: Google\'s AdWords platform uses Generative AI to personalize ads based on user behavior and preferences.\n\nThese are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.'},
#  'done_reason': 'stop',
#  'done': True,
#  'total_duration': 28091981600,
#  'load_duration': 6204576800,
#  'prompt_eval_count': 35,
#  'prompt_eval_duration': 274273000,
#  'eval_count': 480,
#  'eval_duration': 21602840000}

# %%
display(Markdown(response.json()['message']['content']))
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Generation**: AI-powered tools can generate high-quality content such as blog posts, articles, social media posts, product descriptions, and more.
# 2. **Product Design**: Generative AI can assist in designing products by generating 3D models, sketches, and prototypes. This is particularly useful for companies that need to produce complex products quickly.
# 3. **Image and Video Generation**: AI-generated images and videos can be used in advertising, marketing, entertainment, and other industries where visual content is crucial.
# 4. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants, enabling them to generate responses to customer inquiries and provide personalized support.
# 5. **Music Composition and Sound Design**: AI-generated music and sound effects can be used in film scores, video games, and advertising campaigns.
# 6. **Data Analysis and Insights**: Generative AI can analyze large datasets and generate insights, predictions, and recommendations for businesses.
# 7. **Personalization**: AI-powered systems can generate personalized content, offers, and experiences tailored to individual customers' preferences and behaviors.
# 8. **Marketing Automation**: Generative AI can automate marketing tasks such as email marketing, social media management, and lead generation.
# 9. **Virtual Reality (VR) and Augmented Reality (AR)**: AI-generated 3D models and environments can be used in VR and AR experiences, creating immersive and interactive experiences for customers.
# 10. **Supply Chain Optimization**: Generative AI can analyze supply chain data and generate optimized logistics plans, reducing costs and improving efficiency.
#
# Some specific business applications of Generative AI include:
#
# * **Product recommendation engines**: Amazon's "Recommended for you" feature uses Generative AI to suggest products based on user behavior and preferences.
# * **Content marketing platforms**: HubSpot's content management platform uses Generative AI to generate blog posts, social media posts, and other content.
# * **Customer service chatbots**: Many companies use Generative AI-powered chatbots to provide 24/7 customer support.
# * **Personalized advertising**: Google's AdWords platform uses Generative AI to personalize ads based on user behavior and preferences.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %% [markdown]
# # Introducing the ollama package
#
# And now we'll do the same thing, but using the elegant ollama python package instead of a direct HTTP call.
#
# Under the hood, it's making the same call as above to the ollama server running at localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative Artificial Intelligence (AI) has numerous business applications across various industries, including:
#
# 1. **Content Creation**: Generative AI can be used to generate high-quality content such as articles, blog posts, social media posts, and product descriptions, reducing the need for human writers and increasing efficiency.
# 2. **Product Design**: Generative AI can be used to design new products, such as furniture, clothing, or electronics, by generating multiple designs and iterating on them until a desired outcome is achieved.
# 3. **Image and Video Generation**: Generative AI can be used to generate realistic images and videos, which can be used in applications such as advertising, marketing, and entertainment.
# 4. **Chatbots and Virtual Assistants**: Generative AI can be used to power chatbots and virtual assistants, allowing businesses to create more personalized and engaging customer experiences.
# 5. **Predictive Maintenance**: Generative AI can be used to analyze data from sensors and equipment to predict when maintenance is needed, reducing downtime and increasing efficiency.
# 6. **Customer Segmentation**: Generative AI can be used to segment customers based on their behavior, preferences, and demographics, allowing businesses to create more targeted marketing campaigns.
# 7. **Language Translation**: Generative AI can be used to generate high-quality translations of text, speech, and images, reducing the need for human translators and increasing international trade.
# 8. **Audio Generation**: Generative AI can be used to generate realistic audio, such as music, sound effects, or voiceovers, which can be used in applications such as film production, advertising, and gaming.
# 9. **Data Analysis**: Generative AI can be used to analyze large datasets and identify patterns, trends, and insights that may not be apparent through traditional analysis methods.
# 10. **Personalization**: Generative AI can be used to generate personalized content, recommendations, and offers based on individual customer preferences and behavior.
#
# Some specific business applications of Generative AI include:
#
# * **Fashion Brands**: Using Generative AI to design new clothing lines, predict fashion trends, and optimize production processes.
# * **Automotive Companies**: Using Generative AI to design new car models, simulate crashes, and optimize manufacturing processes.
# * **Advertising Agencies**: Using Generative AI to generate high-quality ad copy, images, and videos, and optimize ad campaigns for better results.
# * **Healthcare Organizations**: Using Generative AI to analyze medical data, predict patient outcomes, and optimize treatment plans.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %% [markdown]
# ## Alternative approach - using OpenAI python library to connect to Ollama

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)

# %% [markdown]
# # NOW the exercise for you
#
# Take the code from day1 and incorporate it here, to build a website summarizer that uses Llama 3.2 running locally instead of OpenAI; use either of the above approaches.

# %% [markdown]
# ### Website Summarizer using Ollama

# %%
# create a class for fetching title and text (without irrelevant pieces from html webpage)
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# system prompt
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# user prompt based on website instance
def user_prompt(website):
    user_msg = f"You are looking at a website titled {website.title}"
    user_msg += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_msg+=website.text
    return user_msg

# create main function
def summarizer(url):
    website = Website(url)
    global system_prompt
    system_msg = system_prompt
    user_msg = user_prompt(website)
    
    message_arg = [{"role":"system","content": system_msg},
                   {"role":"user","content": user_msg}]
    # print(message_arg)
    
    response = ollama.chat(model=MODEL, messages=message_arg)
    summary = response['message']['content']
    display(Markdown(summary))

# %%
url = "https://edwarddonner.com"
summarizer(url)
# Out:
# ### Website Summary: Edward Donner's Home Page
#
# #### Overview
# This website belongs to Edward Donner, the co-founder and CTO of Nebula.io. The homepage introduces himself as a passionate AI enthusiast who enjoys writing code, experimenting with Large Language Models (LLMs), and DJing.
#
# #### Projects and Interests
# *   **Nebula.io**: An AI-powered platform that applies machine learning to help people discover their potential and pursue their purpose. Recruiters use this product to source and manage talent.
# *   **Untapt**: A previously founded AI startup acquired in 2021, known for its proprietary LLM matching model and award-winning platform.
#
# #### News and Announcements
# The following news announcements were found on the website:
#
# *   **December 21, 2024**: Welcome message to SuperDataScientists.
# *   **November 13, 2024**: Announcement of Mastering AI and LLM Engineering – Resources.
# *   **October 16, 2024**: Announcement of From Software Engineer to AI Data Scientist – resources.
# *   **August 6, 2024**: Introduction to Outsmart LLM Arena, a battle of diplomacy and deviousness featuring LLMs.
#
# #### Contact Information
# Edward Donner can be reached through his personal email address (`ed [at] edwarddonner [dot] com`) or by following him on social media platforms such as LinkedIn, Twitter, Facebook.
