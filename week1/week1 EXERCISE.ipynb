# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from typing import List
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming
def ask_tutor(question):
    system_prompt = "You are an assitant who answers any questions the user asks in a simplified way with example"
    messages = [{"role":"system","content":system_prompt},
                {"role":"user","content":question}]
    stream = openai.chat.completions.create(model = MODEL_GPT, messages = messages, stream = True)
    
    response = ""
    display_handle = display(Markdown(""),display_id= True)
    
    for chunk in stream:
        response+=chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response),display_id= display_handle.display_id)

# %%
ask_tutor(question)
# Out:
# Sure! Let's break down the code step by step.
#
# ### What the code does:
#
# 1. **List Comprehension with a Set**:
#    - The expression inside the curly braces `{book.get("author") for book in books if book.get("author")}` creates a set of authors from a list of books.
#    - It goes through each `book` in the `books` collection and extracts the "author" attribute.
#    - The `if book.get("author")` part checks if the author exists (is not `None` or an empty string).
#    - Only authors that do exist will be added to the set.
#
# 2. **The `yield from` Statement**:
#    - The `yield from` statement is used in a generator function to yield all values from the provided iterable (in this case, the set of authors).
#    - This means the function will produce each author one by one whenever it is called.
#
# ### Why it does this:
#
# - **Removing Duplicates**: Using a set automatically removes any duplicate authors, ensuring that each author is listed only once.
# ...

# %%
# Get Llama 3.2 to answer
def ask_ollama(question):
    system_prompt = "You are an assitant who answers any questions the user asks in a simplified way with example"
    messages = [{"role":"system","content":system_prompt},
                {"role":"user","content":question}]
    stream = ollama.chat(model=MODEL_LLAMA, messages=messages,stream = True)
    
    response = ""
    display_handle = display(Markdown(""),display_id= True)
    
    for chunk in stream:
        response+=chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response),display_id= display_handle.display_id)

# %%
ask_ollama(question)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ask_ollama(question)
#
# Cell In[9], line 12, in ask_ollama(question)
#       9 display_handle = display(Markdown(""),display_id= True)
#      11 for chunk in stream:
# ---> 12     response+=chunk.choices[0].delta.content or ''
#      13     response = response.replace("```","").replace("markdown", "")
#      14     update_display(Markdown(response),display_id= display_handle.display_id)
#
# File c:\Users\abhid\Desktop\myprojects\llm_engineering\.venv\lib\site-packages\pydantic\main.py:856, in BaseModel.__getattr__(self, item)
#     853     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     854 else:
#     855     # this is the current error
# --> 856     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# ...
